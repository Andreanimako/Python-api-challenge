# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  abengourou   6.7297   -3.4964     27.10        72         100
# 1        1  whitehorse  60.7161 -135.0538      4.06        44          67
# 2        2   adamstown -25.0660 -130.1015     23.60        79          37
# 3        3    tolanaro -25.0319   46.9987     23.88        96          61
# 4        4  codrington -38.2667  141.9667     13.27        82         100
#
#    Wind Speed Country        Date
# 0        2.35      CI  1712693879
# 1        5.36      CA  1712693492
# 2        2.83      PN  1712693694
# 3        3.93      MG  1712693858
# 4        3.22      AU  1712693854

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1= city_data_df.hvplot.points("Lng","Lat",geo=True, tiles="OSM",frame_width = 700, frame_height = 500,size = "Humidity", color = "City")



# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal = city_data_df.loc[(city_data_df["Max Temp"] >21) & (city_data_df["Max Temp"] <27) & (city_data_df["Wind Speed"]<4.5) & (city_data_df["Cloudiness"] == 0) ]
ideal

# Drop any rows with null values
ideal_city= ideal.dropna(how="any")

# Display sample data
ideal_city
# Out:
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 18        18             bethel  41.3712  -73.4140     24.79        32
# 19        19   east porterville  36.0574 -118.9757     23.56        33
# 79        79             broome  42.2506  -75.8330     24.45        33
# 91        91             laguna  38.4210 -121.4238     23.39        45
# 126      126     cabo san lucas  22.8909 -109.9124     25.10        49
# 134      134             teknaf  20.8624   92.3058     25.59        53
# 166      166             medina  24.4686   39.6142     26.24        11
# 196      196  'alaqahdari dishu  30.4374   63.3130     23.58        25
# 215      215            redding  40.5865 -122.3917     26.38        35
# 251      251      half moon bay  37.4636 -122.4286     26.42        61
# 282      282      prudentopolis -25.2131  -50.9778     26.53        58
# 373      373              yanam  16.7333   82.2167     24.15        93
# 453      453             sittwe  20.1500   92.9000     26.70        50
# 477      477             newman  37.3138 -121.0208     22.38        46
# 500      500             murzuq  25.9155   13.9184     23.39        12
# 536      536              beira -19.8436   34.8389     26.05        94
# 556      556            bushehr  28.9684   50.8385     26.05        65
#
#      Cloudiness  Wind Speed Country        Date
# 18            0        2.57      US  1712693454
# 19            0        0.00      US  1712693729
# 79            0        4.02      US  1712693904
# 91            0        1.54      US  1712693714
# 126           0        4.12      MX  1712693532
# 134           0        3.96      BD  1712693741
# 166           0        3.60      SA  1712693922
# 196           0        3.77      AF  1712693928
# 215           0        0.45      US  1712693736
# 251           0        2.57      US  1712693941
# 282           0        1.34      BR  1712693833
# 373           0        0.97      IN  1712693983
# 453           0        4.28      MM  1712694013
# 477           0        0.89      US  1712693837
# 500           0        3.98      LY  1712694032
# 536           0        2.57      MZ  1712694035
# 556           0        3.09      IR  1712693898

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_city[["City","Country", "Lat","Lng","Humidity" ]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=""

# Display sample data
hotel_df
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_11180\1413207297.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"]=""
#                   City Country      Lat       Lng  Humidity Hotel Name
# 18              bethel      US  41.3712  -73.4140        32
# 19    east porterville      US  36.0574 -118.9757        33
# 79              broome      US  42.2506  -75.8330        33
# 91              laguna      US  38.4210 -121.4238        45
# 126     cabo san lucas      MX  22.8909 -109.9124        49
# 134             teknaf      BD  20.8624   92.3058        53
# 166             medina      SA  24.4686   39.6142        11
# 196  'alaqahdari dishu      AF  30.4374   63.3130        25
# 215            redding      US  40.5865 -122.3917        35
# 251      half moon bay      US  37.4636 -122.4286        61
# 282      prudentopolis      BR -25.2131  -50.9778        58
# 373              yanam      IN  16.7333   82.2167        93
# 453             sittwe      MM  20.1500   92.9000        50
# 477             newman      US  37.3138 -121.0208        46
# 500             murzuq      LY  25.9155   13.9184        12
# 536              beira      MZ -19.8436   34.8389        94
# 556            bushehr      IR  28.9684   50.8385        65

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories="accommodation.hotel"
limit= 20
# set up a parameters dictionary
params={
    "categories":categories,
    "limit": limit,
    "format":"json",
    "apiKey":geoapify_key
    }

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude= row["Lat"]
    longitude= row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f'circle:{longitude},{latitude},{radius}'
    params["bias"] = f'proximity:{longitude},{latitude}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params= params)
    
    # Convert the API response to JSON format
    name_address = requests.get(base_url, params= params).json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# bethel - nearest hotel: Hampton Inn Danbury
# east porterville - nearest hotel: Best Western Porterville Inn
# broome - nearest hotel: No hotel found
# laguna - nearest hotel: Holiday Inn Express & Suites
# cabo san lucas - nearest hotel: Comfort Rooms
# teknaf - nearest hotel: No hotel found
# medina - nearest hotel: The Oberoi Madina
# 'alaqahdari dishu - nearest hotel: No hotel found
# redding - nearest hotel: Americana Modern Hotel
# half moon bay - nearest hotel: Half Moon Bay Inn
# prudentopolis - nearest hotel: Hotel Villa Lopes
# yanam - nearest hotel: Hôtel Sarvainn
# sittwe - nearest hotel: Yuzana Aung Motel 1
# newman - nearest hotel: No hotel found
# murzuq - nearest hotel: فندق باريس - مرزق
# beira - nearest hotel: Hotel Savoy
# bushehr - nearest hotel: هتل رستوران سیراف
#                   City Country      Lat       Lng  Humidity  \
# 18              bethel      US  41.3712  -73.4140        32
# 19    east porterville      US  36.0574 -118.9757        33
# 79              broome      US  42.2506  -75.8330        33
# 91              laguna      US  38.4210 -121.4238        45
# 126     cabo san lucas      MX  22.8909 -109.9124        49
# 134             teknaf      BD  20.8624   92.3058        53
# 166             medina      SA  24.4686   39.6142        11
# 196  'alaqahdari dishu      AF  30.4374   63.3130        25
# 215            redding      US  40.5865 -122.3917        35
# 251      half moon bay      US  37.4636 -122.4286        61
# 282      prudentopolis      BR -25.2131  -50.9778        58
# 373              yanam      IN  16.7333   82.2167        93
# 453             sittwe      MM  20.1500   92.9000        50
# 477             newman      US  37.3138 -121.0208        46
# 500             murzuq      LY  25.9155   13.9184        12
# 536              beira      MZ -19.8436   34.8389        94
# 556            bushehr      IR  28.9684   50.8385        65
#
#                        Hotel Name
# 18            Hampton Inn Danbury
# 19   Best Western Porterville Inn
# 79                 No hotel found
# 91   Holiday Inn Express & Suites
# 126                 Comfort Rooms
# 134                No hotel found
# 166             The Oberoi Madina
# 196                No hotel found
# 215        Americana Modern Hotel
# 251             Half Moon Bay Inn
# 282             Hotel Villa Lopes
# 373                Hôtel Sarvainn
# 453           Yuzana Aung Motel 1
# 477                No hotel found
# 500             فندق باريس - مرزق
# 536                   Hotel Savoy
# 556             هتل رستوران سیراف

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2= hotel_df.hvplot.points("Lng","Lat",geo=True, tiles="OSM",frame_width = 700, frame_height = 500,size = "Humidity", color = "City",hover_cols=["Country","Hotel Name"])


# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
